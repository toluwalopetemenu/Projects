# %% [markdown]
# ## Importing Libaries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Loading Data set

# %%
data = pd.read_csv(r"C:\Users\EliteBook\Downloads\Final Assessment Dataset_heart.csv")
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data.isnull().sum()  ##Checking for null values
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### 1.  What's the distribution of participants by gender?

# %%
data.groupby("sex")["target"].count()
# Out:
# sex
# 0    312
# 1    713
# Name: target, dtype: int64

# %% [markdown]
# ## 2. Those with Heart disease, what is their distribution by gender?

# %%
heart_data= (data["target"] == 1)
data2= data[heart_data]
data2
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5      58    0   0       100   248    0        0      122      0      1.0
# 10     71    0   0       112   149    0        1      125      0      1.6
# 12     34    0   1       118   210    0        1      192      0      0.7
# 15     34    0   1       118   210    0        1      192      0      0.7
# 16     51    0   2       140   308    0        0      142      0      1.5
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1011   45    1   1       128   308    0        0      170      0      0.0
# 1014   44    0   2       108   141    0        1      175      0      0.6
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
#
#       slope  ca  thal  target
# 5         1   0     2       1
# ...

# %%
data2.groupby("sex")["target"].count()
# Out:
# sex
# 0    226
# 1    300
# Name: target, dtype: int64

# %%
sns.countplot(data=data2, x='target', hue='sex')
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
data2.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  526.000000  526.000000  526.000000  526.000000  526.000000  526.000000
# mean    52.408745    0.570342    1.378327  129.245247  240.979087    0.134981
# std      9.631804    0.495498    0.945881   16.112188   53.010345    0.342029
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     44.000000    0.000000    1.000000  120.000000  208.000000    0.000000
# 50%     52.000000    1.000000    2.000000  130.000000  234.000000    0.000000
# 75%     59.000000    1.000000    2.000000  140.000000  265.750000    0.000000
# max     76.000000    1.000000    3.000000  180.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  526.000000  526.000000  526.000000  526.000000  526.000000  526.000000
# mean     0.598859  158.585551    0.134981    0.569962    1.593156    0.370722
# ...

# %%
sns.boxplot(data=data2, x="target", y='age', hue='sex')
# Out:
# <AxesSubplot:xlabel='target', ylabel='age'>

# %%
data2.groupby("sex").mean()["age"]
# Out:
# sex
# 0    54.628319
# 1    50.736667
# Name: age, dtype: float64

# %% [markdown]
# ### 3. What is the occurrence of chest pain type among the general population?

# %%
data.groupby('cp').count()
# Out:
#     age  sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# cp
# 0   497  497       497   497  497      497      497    497      497    497
# 1   167  167       167   167  167      167      167    167      167    167
# 2   284  284       284   284  284      284      284    284      284    284
# 3    77   77        77    77   77       77       77     77       77     77
#
#      ca  thal  target
# cp
# 0   497   497     497
# 1   167   167     167
# 2   284   284     284
# 3    77    77      77

# %%
data2.groupby('cp').count()
# Out:
#     age  sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# cp
# 0   122  122       122   122  122      122      122    122      122    122
# 1   134  134       134   134  134      134      134    134      134    134
# 2   219  219       219   219  219      219      219    219      219    219
# 3    51   51        51    51   51       51       51     51       51     51
#
#      ca  thal  target
# cp
# 0   122   122     122
# 1   134   134     134
# 2   219   219     219
# 3    51    51      51

# %%
sns.countplot(data=data, x='cp')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
sns.countplot(data=data2, x='cp')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %% [markdown]
# ### What is the correlation between the occurrence of heart disease and all variables under observation?

# %%
correlation = data.corr()
correlation
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Machine Learning

# %% [markdown]
# #### Baseline; Using Logistics regression on all variables

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
x = data.drop("target", axis=1).values
y = data.target.values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

accuracy_score(y_test, y_pred)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.7853658536585366

# %%
rf = RandomForestClassifier(max_depth = 8, random_state = 42, n_estimators= 1000)
rf.fit(x_train, y_train)

# make predictions
y_pred = rf.predict(x_test)

# evaluate model
accuracy_score(y_test, y_pred)
# Out:
# 0.9853658536585366

# %%
from sklearn.ensemble import GradientBoostingClassifier
gra = GradientBoostingClassifier()
gra.fit(x_train, y_train)


y_pred = gra.predict(x_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.9317073170731708

# %% [markdown]
# ### Droping of some coloumns
# Resting ECG has a weak correlation with the occurrence of heart disease, will therefore be removed
# Cholesterol also has a negative weak correlation and will also be dropped from the dataset
# Alongside fasting blood sugar and trestbps

# %%
df=data.drop(["trestbps", "chol", "fbs", "restecg"], axis=1)
df
# Out:
#       age  sex  cp  thalach  exang  oldpeak  slope  ca  thal  target
# 0      52    1   0      168      0      1.0      2   2     3       0
# 1      53    1   0      155      1      3.1      0   0     3       0
# 2      70    1   0      125      1      2.6      0   0     3       0
# 3      61    1   0      161      0      0.0      2   1     3       0
# 4      62    0   0      106      0      1.9      1   3     2       0
# ...   ...  ...  ..      ...    ...      ...    ...  ..   ...     ...
# 1020   59    1   1      164      1      0.0      2   0     2       1
# 1021   60    1   0      141      1      2.8      1   1     3       0
# 1022   47    1   0      118      1      1.0      1   1     2       0
# 1023   50    0   0      159      0      0.0      2   0     2       1
# 1024   54    1   0      113      0      1.4      1   1     3       0
#
# [1025 rows x 10 columns]

# %%
X= df.drop("target", axis=1).values
Y=df.target.values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler  ##to improve data scalability

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

accuracy_score(Y_test, Y_pred)
# Out:
# 0.8

# %% [markdown]
# #### Random Forest Classifier

# %%
rf = RandomForestClassifier(max_depth = 8, random_state = 42, n_estimators= 1000)
rf.fit(X_train, Y_train)

# make predictions
Y_pred = rf.predict(X_test)

# evaluate model
accuracy_score(Y_test, Y_pred)
# Out:
# 0.9804878048780488

# %% [markdown]
# #### GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gra = GradientBoostingClassifier()
gra.fit(X_train, Y_train)


Y_pred = gra.predict(X_test)

accuracy_score(Y_test, Y_pred)
# Out:
# 0.9317073170731708

# %% [markdown]
# ### Cross Validation

# %%
#Evaluating models
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from numpy import mean
from numpy import std

# %%
# Define models
models = {
    "Logistic Regression": model,
    "Random Forest": rf,
    "Gradient Boosting": gra
}

# %%
# Perform 5-Fold Cross Validation for each model
for name, model in models.items():
    scores = cross_val_score(model, X_train, Y_train, cv=5, scoring='accuracy')  # 5-fold cross-validation
    print(f"{name}: Mean Accuracy = {scores.mean():.4f}, Std Dev = {scores.std():.4f}")
# Out:
# Logistic Regression: Mean Accuracy = 0.8537, Std Dev = 0.0399
# Random Forest: Mean Accuracy = 0.9793, Std Dev = 0.0230
# Gradient Boosting: Mean Accuracy = 0.9524, Std Dev = 0.0206

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn import metrics
import numpy as np

# %%
confusion_matrix = metrics.confusion_matrix(Y_test, Y_pred)

# %%
ConfusionMatrix_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [True, False]).plot()
plt.show()

# %%
print(accuracy_score(Y_test, Y_pred))
# Out:
# 0.9317073170731708

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       102
#            1       0.93      0.93      0.93       103
#
#     accuracy                           0.93       205
#    macro avg       0.93      0.93      0.93       205
# weighted avg       0.93      0.93      0.93       205
